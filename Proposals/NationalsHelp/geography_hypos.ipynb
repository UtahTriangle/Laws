# %%
import wikipedia as wp
data: wp.WikipediaPage = wp.page("List_of_Triangle_chapters")

chapters = {}
for uni in data.links:
    try:
        uni_search = wp.search(uni)[0]
        uni_data: wp.WikipediaPage = wp.page(uni_search)
        chapters[uni_search] = uni_data.coordinates
        print(uni_search, uni_data.coordinates)
    except KeyError as e:
        print(f"{uni} didn't have coordinates available.")
    except wp.PageError as e:
        print(f"{uni} could not be found.")

# %%
hypotheticals = [
    "University of Idaho", # Redundant w/ Washington State U
    "Boise State University",
    "Utah State University",
    "Southern Utah University",
    # "University of Nevada Reno", # REMOVED: Too far away and off mainline - couldn't be justified.
    "Idaho State University",
    # "Washington State University" # Redundant w/ Univerity of Idaho
]

additions = []

for uni in hypotheticals:
    try:
        uni_search = wp.search(uni)[0]
        uni_data: wp.WikipediaPage = wp.page(uni_search)
        additions.append(uni_search)
        chapters[uni_search] = uni_data.coordinates
        print(uni_search, uni_data.coordinates)
    except KeyError as e:
        print(f"{uni} didn't have coordinates available.")
    except wp.PageError as e:
        print(f"{uni} could not be found.")
# Out:
# University of Idaho (Decimal('46.7259999999999990905052982270717620849609375'), Decimal('-117.010999999999995679900166578590869903564453125'))
# Boise State University (Decimal('43.6039999999999992041921359486877918243408203125'), Decimal('-116.2039999999999935198502498678863048553466796875'))
# Utah State University (Decimal('41.74499999999999744204615126363933086395263671875'), Decimal('-111.808999999999997498889570124447345733642578125'))
# Southern Utah University (Decimal('37.6754480000000029349394026212394237518310546875'), Decimal('-113.071631999999993922756402753293514251708984375'))
# Idaho State University (Decimal('42.86099999999999710098563809879124164581298828125'), Decimal('-112.433999999999997498889570124447345733642578125'))

# %%
drops = [
    "United States",
    "Western United States",
    "Eastern United States",
    "Northern United States",
    "Southern United States"
]

for drop in drops:
    if drop in chapters.keys():
        del chapters[drop]
        print(f"{drop} dropped.")
# Out:
# United States dropped.
# Western United States dropped.
# Southern United States dropped.

# %%
for uni, coords in chapters.items():
    chapters[uni] = (
        float(coords[0]),
        float(coords[1])
    )

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopy as gpy
import geopandas as gpd

# %%
df = pd.DataFrame.from_dict(chapters, orient='index', columns=["lat", "long"])

gdf = gpd.GeoDataFrame(
    df,
    geometry = gpd.points_from_xy(
        df.long,
        df.lat
    )
)

gdf.head()
# Out:
#                                                        lat        long  \
# Arizona State University                         33.421000 -111.933000
# California State Polytechnic University, Pomona  34.056389 -117.821667
# Carnegie Mellon University                       40.442500  -79.943333
# Clarkson University                              44.663495  -74.999070
# Clemson University                               34.678333  -82.839167
#
#                                                                     geometry
# Arizona State University                         POINT (-111.93300 33.42100)
# California State Polytechnic University, Pomona  POINT (-117.82167 34.05639)
# Carnegie Mellon University                        POINT (-79.94333 40.44250)
# Clarkson University                               POINT (-74.99907 44.66349)
# Clemson University                                POINT (-82.83917 34.67833)

# %%
drops = [
    "University of Iowa",
    "University of Missouri",
    "Northwestern University",
    "Cornell University",
    "Clarkson College",
    "Kansas State University",
    "Oklahoma State University",
    "Rochester Institute of Technology",
    "University of Colorado",
    "Mississippi State University",
    "University of Connecticut",
    "University of Texas at Arlington",
    "Texas A&M University",
    "Trine University",
    "University of Akron",
    "Northern Illinois University",
    "University of Maryland, Baltimore County",
    "University of Houston",
    "University of California, Berkeley",
    "Florida Atlantic University",
    "Southern Illinois University",
    "University of Arizona",
    "University of Maryland",
    "Mantako State University",
    "Tennessee Technological University",
    "Wright State University",
    "University of Florida",
    "Oregon State University",
    "New Jersey Institute of Technology",
    "Carnegie Mellon University",
    "Florida Institute of Technology",
    "Georgia Institute of Technology",
    "Arizona State University"
]

gdf["Status"] = np.array([int(not i in drops) for i in gdf.index])
gdf
# Out:
#                                                        lat        long  \
# Arizona State University                         33.421000 -111.933000
# California State Polytechnic University, Pomona  34.056389 -117.821667
# Carnegie Mellon University                       40.442500  -79.943333
# Clarkson University                              44.663495  -74.999070
# Clemson University                               34.678333  -82.839167
# ...                                                    ...         ...
# Boise State University                           43.604000 -116.204000
# Utah State University                            41.745000 -111.809000
# Southern Utah University                         37.675448 -113.071632
# University of Nevada, Reno                       39.537778 -119.813889
# Idaho State University                           42.861000 -112.434000
#
#                                                                     geometry  \
# Arizona State University                         POINT (-111.93300 33.42100)
# California State Polytechnic University, Pomona  POINT (-117.82167 34.05639)
# Carnegie Mellon University                        POINT (-79.94333 40.44250)
# Clarkson University                               POINT (-74.99907 44.66349)
# Clemson University                                POINT (-82.83917 34.67833)
# ...                                                                      ...
# Boise State University                           POINT (-116.20400 43.60400)
# Utah State University                            POINT (-111.80900 41.74500)
# Southern Utah University                         POINT (-113.07163 37.67545)
# University of Nevada, Reno                       POINT (-119.81389 39.53778)
# Idaho State University                           POINT (-112.43400 42.86100)
#
#                                                  Status
# Arizona State University                              0
# California State Polytechnic University, Pomona       1
# Carnegie Mellon University                            0
# Clarkson University                                   1
# Clemson University                                    1
# ...                                                 ...
# Boise State University                                1
# Utah State University                                 1
# Southern Utah University                              1
# University of Nevada, Reno                            1
# Idaho State University                                1
#
# [72 rows x 4 columns]

# %%
import geopy as gpy
import geopandas as gpd

world = gpd.read_file("data/States_shapefile.shp")
world
# Out:
#     FID          Program State_Code            State_Name Flowing_St  FID_1  \
# 0     1  PERMIT TRACKING         AL               ALABAMA          F    919
# 1     2             None         AK                ALASKA          N    920
# 2     3          AZURITE         AZ               ARIZONA          F    921
# 3     4              PDS         AR              ARKANSAS          F    922
# 4     5             None         CA            CALIFORNIA          N    923
# 5     6           ECOMAP         CO              COLORADO          F    924
# 6     7             SIMS         CT           CONNECTICUT          F    925
# 7     8             None         DE              DELAWARE          P    926
# 8     9             None         DC  DISTRICT OF COLUMBIA          P    927
# 9    10             None         FL               FLORIDA          P    928
# 10   11             None         GA               GEORGIA          N    929
# 11   12           HI-EHW         HI                HAWAII          F    930
# 12   13             None         ID                 IDAHO          P    931
# 13   14             ACES         IL              ILLINOIS          F    932
# 14   15           IN-FRS         IN               INDIANA          F    933
# 15   16         IDNR_EFD         IA                  IOWA          F    934
# 16   17            KS-FP         KS                KANSAS          F    935
# 17   18         KY-TEMPO         KY              KENTUCKY          F    936
# 18   19             None         LA             LOUISIANA          P    937
# 19   20          ME-EFIS         ME                 MAINE          F    938
# 20   21             None         MD              MARYLAND          P    939
# 21   22         MA-EPICS         MA         MASSACHUSETTS          F    940
# 22   23             None         MI              MICHIGAN          P    941
# 23   24         MN-DELTA         MN             MINNESOTA          F    942
# 24   25        MS-ENSITE         MS           MISSISSIPPI          F    943
# 25   26           MO-DNR         MO              MISSOURI          F    944
# 26   27        MT-CEDARS         MT               MONTANA          F    945
# 27   28             NDEQ         NE              NEBRASKA          F    946
# 28   29            NV-FP         NV                NEVADA          F    947
# 29   30           NH-DES         NH         NEW HAMPSHIRE          F    948
# 30   31         NJ-NJEMS         NJ            NEW JERSEY          F    949
# 31   32             None         NM            NEW MEXICO          P    950
# 32   33              FIS         NY              NEW YORK          F    951
# 33   34             None         NC        NORTH CAROLINA          N    952
# 34   35             None         ND          NORTH DAKOTA          N    953
# 35   36             None         OH                  OHIO          P    954
# 36   37           OK-FMS         OK              OKLAHOMA          F    955
# 37   38             None         OR                OREGON          N    956
# 38   39        PA-EFACTS         PA          PENNSYLVANIA          F    957
# 39   40             None         RI          RHODE ISLAND          N    958
# 40   41             None         SC        SOUTH CAROLINA          N    959
# 41   42             None         SD          SOUTH DAKOTA          P    960
# 42   43             None         TN             TENNESSEE          P    961
# 43   44      TX-TCEQ ACR         TX                 TEXAS          F    962
# 44   45             None         UT                  UTAH          N    963
# 45   46             None         VT               VERMONT          P    964
# 46   47             None         VA              VIRGINIA          P    965
# 47   48          WA-FSIS         WA            WASHINGTON          F    966
# 48   49             None         WV         WEST VIRGINIA          N    967
# 49   50           WI-ESR         WI             WISCONSIN          F    968
# 50   51             None         WY               WYOMING          N    969
#
#                                              geometry
# 0   POLYGON ((-85.07007 31.98070, -85.11515 31.907...
# 1   MULTIPOLYGON (((-161.33379 58.73325, -161.3824...
# 2   POLYGON ((-114.52063 33.02771, -114.55909 33.0...
# 3   POLYGON ((-94.46169 34.19677, -94.45262 34.508...
# 4   MULTIPOLYGON (((-121.66522 38.16929, -121.7823...
# 5   POLYGON ((-102.04446 37.64147, -102.04201 37.3...
# 6   POLYGON ((-73.53039 41.52275, -73.51715 41.665...
# 7   POLYGON ((-75.70707 38.55759, -75.71071 38.649...
# 8   POLYGON ((-77.00793 38.96667, -76.91090 38.890...
# 9   MULTIPOLYGON (((-80.78566 28.78519, -80.76242 ...
# 10  MULTIPOLYGON (((-85.13016 31.77885, -85.13156 ...
# 11  MULTIPOLYGON (((-160.07380 22.00418, -160.0497...
# 12  POLYGON ((-117.02630 43.67903, -117.02379 43.7...
# 13  POLYGON ((-88.07159 37.51104, -88.08791 37.476...
# 14  POLYGON ((-86.34161 38.17729, -86.36435 38.193...
# 15  POLYGON ((-91.12013 40.70544, -91.12930 40.682...
# 16  POLYGON ((-95.07193 37.00148, -95.40662 37.000...
# 17  MULTIPOLYGON (((-86.51067 36.65507, -86.77054 ...
# 18  MULTIPOLYGON (((-93.70752 30.23958, -93.69938 ...
# 19  MULTIPOLYGON (((-69.77728 44.07415, -69.85993 ...
# 20  MULTIPOLYGON (((-75.71071 38.64967, -75.70707 ...
# 21  MULTIPOLYGON (((-71.31933 41.77220, -71.33980 ...
# 22  MULTIPOLYGON (((-88.49753 48.17380, -88.62533 ...
# 23  POLYGON ((-91.73037 43.49957, -92.07753 43.499...
# 24  POLYGON ((-88.45080 31.43562, -88.43456 31.120...
# 25  POLYGON ((-89.10503 36.95392, -89.12965 36.866...
# 26  POLYGON ((-111.47543 44.70216, -111.48080 44.6...
# 27  POLYGON ((-101.40739 40.00100, -102.05154 39.9...
# 28  POLYGON ((-119.15245 38.41180, -119.31883 38.5...
# 29  POLYGON ((-72.27992 42.72047, -72.45577 42.725...
# 30  POLYGON ((-75.48928 39.71486, -75.47597 39.720...
# 31  POLYGON ((-109.04950 32.44204, -109.05135 32.7...
# 32  MULTIPOLYGON (((-79.76323 42.26733, -79.44402 ...
# 33  MULTIPOLYGON (((-83.98845 34.98915, -84.11815 ...
# 34  POLYGON ((-98.73044 45.93827, -99.00683 45.939...
# 35  POLYGON ((-83.27275 38.60926, -83.29004 38.596...
# 36  POLYGON ((-94.43932 34.92915, -94.44596 34.735...
# 37  POLYGON ((-121.44151 41.99433, -122.28471 42.0...
# 38  POLYGON ((-77.47579 39.71962, -78.09595 39.725...
# 39  MULTIPOLYGON (((-71.79019 41.60131, -71.79261 ...
# 40  MULTIPOLYGON (((-81.75959 33.19538, -81.76988 ...
# 41  POLYGON ((-102.78838 42.99530, -103.00588 42.9...
# 42  POLYGON ((-83.95461 35.45554, -84.01256 35.407...
# 43  MULTIPOLYGON (((-105.99889 31.39394, -106.2132...
# 44  POLYGON ((-114.04727 38.13765, -114.04509 38.5...
# 45  POLYGON ((-73.25806 42.74606, -73.26928 42.747...
# 46  MULTIPOLYGON (((-79.14406 36.54620, -79.21680 ...
# 47  MULTIPOLYGON (((-122.40202 48.22522, -122.4628...
# 48  POLYGON ((-79.23166 38.48050, -79.27236 38.437...
# 49  MULTIPOLYGON (((-87.74855 44.96162, -87.83999 ...
# 50  POLYGON ((-104.05362 41.69822, -104.05550 41.5...

# %%
ax = world[world.State_Code != "AK"].plot()
plt.xlim([-130, -65])
plt.ylim([25, 50])

color_map = {
    0: "#CCCCCC",
    1: "#FF0000"
}

gdf.plot(
    ax=ax,
    color=gdf["Status"].map(color_map)
)

plt.show()

# %%
import json
import requests
import yaml

with open(r'secrets.yaml') as file:
    API_KEY = yaml.load(file, Loader=yaml.FullLoader)["API_KEY"]

def get_travel_time(orig, dest):

    # google API url 
    url = f"https://maps.googleapis.com/maps/api/distancematrix/json?units=imperial&origins={orig}&destinations={dest}&key={API_KEY}"

    r = requests.get(url)

    results = json.loads(r.content)
    try:
        duration = results['rows'][0]['elements'][0]['duration']
        return duration['value'] / 3600
    except Exception as e:
        print(results)
        print(e)

# %%
from geopy.distance import geodesic

closest_chapter = {}
closest_dist = {}
closest_time = {}

for chapter in gdf.index:
    closest_chapter[chapter] = None
    closest_dist[chapter] = 1e10

    for neighbor in gdf.index:
        if neighbor == chapter:
            continue

        chap = gdf.loc[chapter ]
        neig = gdf.loc[neighbor]

        if neig.Status == 0:
            continue

        dist = geodesic(
            (chap.lat, chap.long),
            (neig.lat, neig.long)
        ).mi

        if dist < closest_dist[chapter]:
            closest_chapter[chapter] = neighbor
            closest_dist[chapter] = dist

    # Once closest is found, calc travel time
    closest_time[chapter] = get_travel_time(chapter, closest_chapter[chapter])

# %%
hq_addr = "120 South Center Street Plainfield, Indiana"
hq_latlong = (39.70215652386097, -86.40291718918972)
hq_dist = {}
hq_time = {}

for chapter in gdf.index:
    hq_dist[chapter] = geodesic(
        (gdf.loc[chapter].lat, gdf.loc[chapter].long),
        (hq_latlong[0], hq_latlong[1])
    )

    hq_time[chapter] = get_travel_time(chapter, hq_addr)

# %%
gdf["Closest Chapter"] = pd.Series(closest_chapter)
gdf["Closest Dist"] = pd.Series(closest_dist)
gdf["Closest Time"] = pd.Series(closest_time)
gdf["HQ Dist"] = pd.Series(hq_dist)
gdf["HQ Time"] = pd.Series(hq_time)
gdf[gdf.Status == 1].sort_values(by="Closest Time")
# Out:
#                                                        lat        long  \
# University of Wisconsin–Milwaukee                43.075030  -87.882915
# Marquette University                             43.039167  -87.932500
# California State Polytechnic University, Pomona  34.056389 -117.821667
# University of California, Irvine                 33.645556 -117.842500
# University of California, Los Angeles            34.069444 -118.445278
# University of Michigan                           42.276944  -83.738056
# University of Toledo                             41.657716  -83.613660
# Michigan State University                        42.725000  -84.480000
# University of California, San Diego              32.880100 -117.234000
# Colorado State University                        40.574836 -105.080978
# University of Colorado Boulder                   40.006667 -105.267222
# University of Wisconsin–Madison                  43.075000  -89.417222
# University of Kentucky                           38.033333  -84.500000
# University of Louisville                         38.215000  -85.760278
# University of Oklahoma                           35.208611  -97.445833
# Oklahoma State University–Stillwater             36.132222  -97.080833
# University of Minnesota                          44.974747  -93.235353
# Minnesota State University, Mankato              44.146617  -93.998117
# University of Cincinnati                         39.131000  -84.516000
# Illinois Institute of Technology                 41.834653  -87.628333
# University of Utah                               40.765000 -111.850000
# Utah State University                            41.745000 -111.809000
# Idaho State University                           42.861000 -112.434000
# University of Illinois Urbana-Champaign          40.110556  -88.228333
# Ohio State University                            40.000000  -83.012500
# Rose–Hulman Institute of Technology              39.482500  -87.324167
# Purdue University                                40.424000  -86.929000
# Clemson University                               34.678333  -82.839167
# Georgia Tech                                     33.775833  -84.394722
# University of Maryland, College Park             38.987500  -76.940000
# Virginia Commonwealth University                 37.546615  -77.453255
# Penn State Erie, The Behrend College             42.119402  -79.988773
# University of Pittsburgh                         40.444565  -79.953274
# University of North Carolina at Charlotte        35.303556  -80.732381
# University of Maryland, College Park              9.443333
# Virginia Commonwealth University                 10.122500
# Penn State Erie, The Behrend College              6.571944
# University of Pittsburgh                          5.965833
# University of North Carolina at Charlotte         9.400556
# Pennsylvania State University                     8.173889
# Virginia Tech                                     7.599167
# Northeastern United States                       12.108333
# Clarkson University                              12.227222
# Iowa State University                             7.393056
# University of Nebraska–Lincoln                    9.797222
# University of Kansas                              7.748333
# Boise State University                           26.641111
# Southern Utah University                         24.136111
# Missouri University of Science and Technology     5.139444
# University of Washington                         33.053056
# South Dakota School of Mines and Technology      15.918056
# University of Idaho                              29.757222
# Michigan Technological University                 9.687222

# %%
import seaborn as sns
from matplotlib.gridspec import GridSpec

# %%
# %matplotlib inline

# %%
sns.set_theme()
plt.tight_layout()

fig: plt.Figure = plt.figure(figsize=(28, 16))
fig.subplots_adjust(top=0.95)
gs = GridSpec(nrows=3, ncols=3)

agdf = gdf.drop(gdf[gdf.Status == 0].index)
agdf["Closest Median"] = agdf["Closest Time"] - agdf["Closest Time"].median()
agdf["Closest Average"] = agdf["Closest Time"] - agdf["Closest Time"].mean()
agdf["HQ Median"] = agdf["HQ Time"] - agdf["HQ Time"].median()
agdf["HQ Average"] = agdf["HQ Time"] - agdf["HQ Time"].mean()
agdf["Isolated"] = np.logical_and(
    (agdf["Closest Average"] >= 0),
    (agdf["HQ Average"] >= 0)
).astype(int)

world = gpd.read_file("data/States_shapefile.shp")

# ==========
# GRID
# ==========

cl_map: plt.Axes = fig.add_subplot(gs[0,0])
cl_abs: plt.Axes = fig.add_subplot(gs[0,1])
cl_rel: plt.Axes = fig.add_subplot(gs[0,2])

hq_map: plt.Axes = fig.add_subplot(gs[1,0])
hq_abs: plt.Axes = fig.add_subplot(gs[1,1])
hq_rel: plt.Axes = fig.add_subplot(gs[1,2])

iso_map: plt.Axes = fig.add_subplot(gs[2, :])

# ==========
# LIMITS
# ==========
cl_abs.set_xlim([0, 13])
cl_rel.set_xlim([-2.5, 11])

hq_abs.set_xlim([0, 34])
hq_rel.set_xlim([-10, 23])


# ==========
# CLOSEST
# ==========

cl_df = agdf.sort_values(by="Closest Time")
cl_colors = (cl_df["Closest Average"] >= 0).astype(int)
for add in additions:
    cl_colors.at[add] = 2
cl_colors.at["University of Utah"] = 3
cl_colors = cl_colors.map({
    0: "#B7B8B6",
    1: "#EFB4AC",
    2: "#90AFC5",
    3: "#FF0000"
})

cl_map.set_xlim([-130, -65])
cl_map.set_ylim([25, 49])
cl_map.xaxis.set_ticklabels([])
cl_map.yaxis.set_ticklabels([])
cl_map.set_facecolor("#FFFFFF")
world.plot(
    ax = cl_map,
    color = "#E2E2E2",
    edgecolor="#FFFFFF",
    # linewidth=4
)

# Add lines between closest neighbors
for chapter in cl_df.index:
    orig = cl_df.loc[chapter].geometry
    dest = cl_df.loc[cl_df.loc[chapter]["Closest Chapter"]].geometry
    cl_map.plot(
        [orig.x, dest.x],
        [orig.y, dest.y],
        linestyle = "dotted",
        color = "#444444",
        zorder=1
    )

cl_df["geometry"].plot(
    ax = cl_map,
    color = cl_colors,
    zorder=2
)

cl_abs.set_facecolor("#F2F2F2")
cl_abs.barh(
    cl_df.index,
    cl_df["Closest Time"],
    color = cl_colors,
    height = 1
)
cl_abs.yaxis.set_ticklabels([])
cl_abs.set_ylabel("Active Chapters")
cl_abs.set_xlabel("Driving Hours")

cl_rel.set_facecolor("#F2F2F2")
cl_rel.barh(
    cl_df.index,
    cl_df["Closest Average"],
    color = cl_colors,
    height = 1
)
cl_rel.yaxis.set_ticklabels([])
cl_rel.set_ylabel("")
cl_rel.set_xlabel("Driving Hours from Average")


# ==========
# HQ
# ==========

hq_df = agdf.sort_values(by="HQ Time")
hq_colors = (hq_df["HQ Average"] >= 0).astype(int)
for add in additions:
    hq_colors.at[add] = 2
hq_colors.at["University of Utah"] = 3
hq_colors = hq_colors.map({
    0: "#B7B8B6",
    1: "#EFB4AC",
    2: "#90AFC5",
    3: "#FF0000"
})

hq_map.set_xlim([-130, -65])
hq_map.set_ylim([25, 49])
hq_map.xaxis.set_ticklabels([])
hq_map.yaxis.set_ticklabels([])
hq_map.set_facecolor("#FFFFFF")
world.plot(
    ax = hq_map,
    color = "#E2E2E2",
    edgecolor="#FFFFFF",
    # linewidth=4
)

# Add lines between closest neighbors
for chapter in hq_df.index:
    orig = hq_df.loc[chapter].geometry
    hq_map.plot(
        [orig.x, hq_latlong[1]],
        [orig.y, hq_latlong[0]],
        linestyle = "dotted",
        color = "#444444",
        zorder=1
    )

hq_df["geometry"].plot(
    ax = hq_map,
    color = hq_colors,
    zorder=2
)

hq_abs.set_facecolor("#F2F2F2")
hq_abs.barh(
    hq_df.index,
    hq_df["HQ Time"],
    color = hq_colors,
    height = 1
)
hq_abs.yaxis.set_ticklabels([])
hq_abs.set_ylabel("Active Chapters")
hq_abs.set_xlabel("Driving Hours")


hq_rel.set_facecolor("#F2F2F2")
hq_rel.barh(
    hq_df.index,
    hq_df["HQ Average"],
    color = hq_colors,
    height = 1
)
hq_rel.yaxis.set_ticklabels([])
hq_rel.set_ylabel("")
hq_rel.set_xlabel("Driving Hours from Average")


# ==========
# ISOLATED
# ==========

iso_colors = agdf["Isolated"]
iso_colors.at["University of Utah"] = 2
iso_colors = iso_colors.map({
    0: "#B7B8B6",
    1: "#EFB4AC",
    2: "#FF0000"
})

BIG = 40
SMALL = 20
iso_sizes = (agdf["Isolated"] * BIG) + SMALL

iso_map.set_xlim([-130, -65])
iso_map.set_ylim([25, 49])
iso_map.xaxis.set_ticklabels([])
iso_map.yaxis.set_ticklabels([])
iso_map.set_facecolor("#FFFFFF")
world.plot(
    ax = iso_map,
    color = "#E2E2E2",
    edgecolor="#FFFFFF",
    # linewidth=4
)

agdf["geometry"].plot(
    ax = iso_map,
    color = iso_colors,
    zorder=2,
    markersize = iso_sizes
)


plt.savefig("figures/distances_hypo.pdf", format="pdf", dpi=750)
plt.show()
